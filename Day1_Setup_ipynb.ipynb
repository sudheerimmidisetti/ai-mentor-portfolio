# %% [markdown]
# <a href="https://colab.research.google.com/github/sudheerimmidisetti/ai-mentor-portfolio/blob/main/Day1_Setup_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid is a hierarchical model outlining the diverse expertise needed to successfully develop, deploy, and manage AI systems:
#
# *   **Foundation (Data & Algorithms):** The base consists of **Data Collection & Engineering** (gathering, cleaning, storing data) and **Model Development** (choosing, training, and evaluating ML algorithms).
# *   **Deployment & Integration:** Mid-layers involve **MLOps (Machine Learning Operations)** to reliably deploy and monitor models in production, and **Application Development** to integrate AI into specific products or services with domain expertise.
# *   **Strategic & Ethical Leadership:** The apex represents **Strategy & Ethics**, focusing on aligning AI initiatives with business goals, ensuring responsible AI practices, and understanding societal impact.
# *   **Holistic Approach:** It emphasizes that effective AI solutions require a multidisciplinary team, building from raw data infrastructure up to strategic oversight and ethical considerations.
